# %%
from bandits import UCBBanditsTestBed
import matplotlib.pyplot as plt
#print(plt.style.available)
plt.style.use("dark_background")

bandits = UCBBanditsTestBed(arms=10, confidence_factor=[0.01, 1, 10], samples=1000, iterations=1000, reward_size=10, partitions=1024)
bandits.run_testbed()

# %%
bandits.plot_arms()

# %%
bandits.plot_avg_rewards()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/sharoon/Desktop/git/easy-bandits/easy_bandits/test.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/sharoon/Desktop/git/easy-bandits/easy_bandits/test.ipynb#ch0000002?line=0'>1</a> bandits.plot_avg_rewards()
#
# File ~/Desktop/git/easy-bandits/easy_bandits/bandits/ucb_bandits.py:139, in UCBBanditsTestBed.plot_avg_rewards(self)
#     137     self.rewards_per_iteration = self.rewards_per_iteration.reshape(1, -1)
#     138 for j, i in enumerate(self.confidence):
# --> 139     plt.plot(
#     140         xlab, self.rewards_per_iteration[j], label="confidence_factor = {}".format(i)
#     141     )
#     142 plt.xlabel("Iteration")
#     143 plt.ylabel("Average Reward")
#
# ...

# %%
import numpy as np
x = np.array([[1,2]])
x.reshape(1,-1)
# Out:
# array([[1, 2]])

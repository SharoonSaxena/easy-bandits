# %%
from bandits import OptimisticBanditsTestBed
import matplotlib.pyplot as plt
#print(plt.style.available)
plt.style.use("dark_background")

bandits = OptimisticBanditsTestBed(arms=10, epsilon=0.1, optimism_factor= [0, 0.01, 0.1, 1, 10], samples=1000, iterations=1000, reward_size=10, partitions=1024)
bandits.run_testbed()

# %%
bandits.plot_arms()

# %%
bandits.plot_avg_rewards()

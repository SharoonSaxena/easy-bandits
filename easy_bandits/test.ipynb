# %%
from bandits import ClassicBanditsTestBed
import matplotlib.pyplot as plt
#print(plt.style.available)
plt.style.use("dark_background")

bandits = ClassicBanditsTestBed(arms=10, epsilon=[0.01, 0.1, 0.001], samples=10000, iterations=1000, reward_size=10, partitions=1024)
bandits.run_testbed()

# %%
bandits.plot_arms()

# %%
bandits.plot_avg_rewards()

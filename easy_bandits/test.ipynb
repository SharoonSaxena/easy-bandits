# %%
import matplotlib.pyplot as plt
#print(plt.style.available)
plt.style.use("dark_background")
from bandits import BanditsTestBed

bandits = BanditsTestBed(arms=10, epsilon=[0.01, 0.1, 0.001], samples=10000, iterations=1000, reward_size=10, n_jobs=1024)
bandits.run_testbed()

# %%
bandits.plot_arms()

# %%
bandits.plot_avg_rewards()
